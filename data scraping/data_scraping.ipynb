# %%
import pandas as pd 
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# ## Create driver

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
time.sleep(5)
page_url = 'https://you-zitsu.fandom.com/wiki/Category:Characters'
driver.get(page_url)

# %%
from selenium.webdriver.common.by import By
driver.find_element(By.XPATH, '//div[text()="ACCEPT"]').click()

# %% [markdown]
# ## Getting the characters from the website

# %%
characters = driver.find_elements(By.CLASS_NAME, 'category-page__member-link')
character_list=[]
for character in characters:
    character_list.append({'character': character.text})

    
pd.set_option("display.max_rows", None)    
japanese_character_df = pd.DataFrame(character_list)
japanese_character_df
# Out:
#                    character
# 0                Airi Sakura
# 1            Akane Tachibana
# 2               Akito Miyake
# 3              Albert Yamada
# 4           Arisu Sakayanagi
# 5        Chairman Sakayanagi
# 6          Chiaki Matsushita
# 7           Chie Hoshinomiya
# 8          Chihiro Shiranami
# 9            Daichi Ishizaki
# 10           Category:Female
# 11              Fūka Kiryūin
# 12             Haruka Hasebe
# 13           Haruki Yamauchi
# 14               Hayato Kitō
# 15            Hideo Sotomura
# 16             Hiroya Tokitō
# 17             Hiyori Shiina
# 18           Honami Ichinose
# 19            Ichika Amasawa
# 20            Ikuto Kiriyama
# 21              Kakeru Ryūen
# 22                 Kanji Ike
# 23           Katsunori Shiba
# 24            Kayano Onodera
# 25           Kazuma Sakagami
# 26             Kazuomi Hōsen
# 27             Kei Karuizawa
# 28                  Ken Sudō
# 29             Kikyō Kushida
# 30        Kiyotaka Ayanokōji
# 31         Kokoro Inogashira
# 32              Kyō Ishigami
# 33              Kyōgo Komiya
# 34           Kyōsuke Okitani
# 35           Kōhei Katsuragi
# 36              Kōji Machida
# 37              Mako Amikura
# 38             Category:Male
# 39           Manabu Horikita
# 40       Masayoshi Hashimoto
# 41             Masumi Kamuro
# 42                 Maya Satō
# 43               Mei-Yu Wang
# 44             Miki Yamamura
# 45          Minori Kinoshita
# 46                 Mio Ibuki
# 47  Miscellaneous Characters
# 48             Miyabi Nagumo
# 49               Nanami Yabu
# 50            Nazuna Asahina
# 51                 Nene Mori
# 52       Professor Ayanokōji
# 53                 Reo Kondō
# 54             Rika Morofuji
# 55              Riku Utomiya
# 56           Rokusuke Kōenji
# 57             Ryōtarō Hondō
# 58             Ryūji Kanzaki
# 59            Sae Chabashira
# 60            Saki Yamashita
# 61          Sakurako Tsubaki
# 62             Satoru Kaneda
# 63         Satsuki Shinohara
# 64                 Sayo Andō
# 65              Shiho Manabe
# 66         Category:Students
# 67           Suzune Horikita
# 68                Sō Shibata
# 69            Sōshi Miyamoto
# 70            Takeko Nishino
# 71             Takuya Yagami
# 72         Category:Teachers
# 73         Teruhiko Yukimura
# 74         Tetsuya Hamaguchi
# 75          Tomonari Mashima
# 76            Tsubasa Nanase
# 77                Tsukishiro
# 78            Yahiko Totsuka
# 79               Yuki Himeno
# 80            Yukitsu Kusuda
# 81              Yume Kobashi
# 82             Yōsuke Hirata

# %% [markdown]
# ## Cleaning data

# %%
def cleaner(df):
    df['character reverse'] = df['character'].apply(lambda x: " ".join(reversed(x.split())))

    df['firstname'] = df['character'].apply(lambda x: x.split(' ')[0])
    df['lastname'] = df['character'].apply(lambda x: x.split(' ')[1])

    # having the same last name leads to problems so for the non main characters who have repeating last names we change them

    horikitas_df = df[df['lastname'] == 'Horikita']
    ayanos_df = df[df['lastname'] == 'Ayanokouji']
    japanese_ayanos_df = df[df['lastname'] == 'Ayanokōji']

    horikita_index = horikitas_df.index[horikitas_df['firstname'] == 'Manabu'].tolist()
    ayano_index = ayanos_df.index[ayanos_df['firstname'] == 'Atsuomi'].tolist()
    japanese_ayanos_index = japanese_ayanos_df.index[japanese_ayanos_df['firstname'] == 'Atsuomi'].tolist()

    df['lastname'][horikita_index] = 'None'
    df['lastname'][ayano_index] = 'Impossible'
    df['lastname'][japanese_ayanos_index] = 'Impossible'

# %%
pattern = "Category"
filterMask = japanese_character_df['character'].str.contains(pattern)
japanese_character_df = japanese_character_df[~filterMask].copy()

character_df = pd.DataFrame()

# Tsukishiro needs to have firstname Tokinari
# Professor Ayanokouji needs to have firstname Atsuomi
# Sae has a different last name in our transalated books

japanese_character_df['character'][77] = 'Tokinari Tsukishiro'
japanese_character_df['character'][51] = 'Atsuomi Ayanokōji'
japanese_character_df['character'][58] = 'Sae Chiyabashira'


character_df['character'] = (japanese_character_df['character'].apply(lambda x: x.replace('ō', 'ou'))).copy().apply(lambda x: x.replace('ū', 'uu')).copy()

cleaner(japanese_character_df)
cleaner(character_df)

character_df['display name'] = character_df['character']
japanese_character_df['display name'] = (japanese_character_df['character'].apply(lambda x: x.replace('ō', 'ou'))).copy().apply(lambda x: x.replace('ū', 'uu')).copy()
character_df
# Out:
#                    character         character reverse      firstname  \
# 0                Airi Sakura               Sakura Airi           Airi
# 1            Akane Tachibana           Tachibana Akane          Akane
# 2               Akito Miyake              Miyake Akito          Akito
# 3              Albert Yamada             Yamada Albert         Albert
# 4           Arisu Sakayanagi          Sakayanagi Arisu          Arisu
# 5        Chairman Sakayanagi       Sakayanagi Chairman       Chairman
# 6          Chiaki Matsushita         Matsushita Chiaki         Chiaki
# 7           Chie Hoshinomiya          Hoshinomiya Chie           Chie
# 8          Chihiro Shiranami         Shiranami Chihiro        Chihiro
# 9            Daichi Ishizaki           Ishizaki Daichi         Daichi
# 11            Fuuka Kiryuuin            Kiryuuin Fuuka          Fuuka
# 12             Haruka Hasebe             Hasebe Haruka         Haruka
# 13           Haruki Yamauchi           Yamauchi Haruki         Haruki
# 14              Hayato Kitou              Kitou Hayato         Hayato
# 15            Hideo Sotomura            Sotomura Hideo          Hideo
# 16            Hiroya Tokitou            Tokitou Hiroya         Hiroya
# 17             Hiyori Shiina             Shiina Hiyori         Hiyori
# 18           Honami Ichinose           Ichinose Honami         Honami
# 19            Ichika Amasawa            Amasawa Ichika         Ichika
# 20            Ikuto Kiriyama            Kiriyama Ikuto          Ikuto
# 21             Kakeru Ryuuen             Ryuuen Kakeru         Kakeru
# 22                 Kanji Ike                 Ike Kanji          Kanji
# 23           Katsunori Shiba           Shiba Katsunori      Katsunori
# 24            Kayano Onodera            Onodera Kayano         Kayano
# 25           Kazuma Sakagami           Sakagami Kazuma         Kazuma
# 26            Kazuomi Housen            Housen Kazuomi        Kazuomi
# 27             Kei Karuizawa             Karuizawa Kei            Kei
# 28                 Ken Sudou                 Sudou Ken            Ken
